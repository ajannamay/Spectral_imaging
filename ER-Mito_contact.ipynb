# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reload all modules imported with %aimport every time before executing the Python code typed
# use if constantly editing .py script
# %load_ext autoreload
# %autoreload 1
# %aimport Spectral_Analysis

# %%
# Set the Seaborn style and palette
sns.set(style="ticks",palette="deep")

# %%
FOV3_1 = Spectral_Analysis.Spectra('C:\\Users\\admin\\OneDrive - Washington University in St. Louis\\PhD\\Research\\Biophys\\image_data\\ER-Mito_contact\\FOV3_1',
                                'C:\\Users\\admin\\OneDrive - Washington University in St. Louis\\PhD\\Research\\Biophys\\image_data\\ER-Mito_contact\\FOV3_1unmix',
                                6,1024,25,0,'ER','M',484)

# %%
plotter, ERindx, Mindx = FOV3_1.generate_scatter_plot(True,100)
plt.legend(loc='upper right')
# sns.despine()
plt.show()

# %%
FOV3_1.generate_normSpectrum(ERindx,0,False,'ER')
FOV3_1.generate_normSpectrum(Mindx,0,False,'M')
# plt.ylim(top=4000)
plt.legend()
# sns.despine()
plt.show()

# %%
mixed = FOV3_1.pix_mask('C:\\Users\\admin\\OneDrive - Washington University in St. Louis\\PhD\\Research\\Biophys\\image_data\\ER-Mito_contact\\FOV3_1posscontacts')

# %%
FOV3_1.generate_normSpectrum(mixed,0,True,'mixed')
plt.legend()
plt.show()

# %%
len(mixed[0])
# Out:
# 115

# %%
bkg_in = FOV3_1.pix_mask('C:\\Users\\admin\\OneDrive - Washington University in St. Louis\\PhD\\Research\\Biophys\\image_data\\ER-Mito_contact\\FOV3_1insidecells3')

# %%
FOV3_1.generate_normSpectrum(bkg_in,0,True,'bkg')
plt.legend()
plt.show()

# %%
FOV3_1.generate_normSpectrum(bkg_in,0,True,'bkg')
FOV3_1.generate_normSpectrum(mixed,0,True,'mixed')
plt.legend()
plt.show()

# %%
len(bkg_in[0])
# Out:
# 49
