# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reload all modules imported with %aimport every time before executing the Python code typed
# use if constantly editing .py script
# %load_ext autoreload
# %autoreload 1
# %aimport Spectral_Analysis

# %%
# if no longer editing .py script, import the class instead
import Spectral_Analysis

# %%
# Set the Seaborn style and palette
sns.set(style="darkgrid",palette="deep")

# %%
test1 = Spectral_Analysis.Spectra(False,
                                'C:\\Users\\admin\\Downloads\\09-25-24-selected\\mKO2_spectral_FOV3',
                                'C:\\Users\\admin\\Downloads\\09-25-24-selected\\mKO2_spectral_unmixed_FOV3',
                                6,512,20,12,'M','LD',532)

# %%
plotter, Mindx, LDindx = test1.generate_scatter_plot(False,100)
plt.legend(loc='upper right')
plt.show()

# %%
test1.generate_normSpectrum(Mindx,0,True,"mKO2-M")
test1.generate_normSpectrum(LDindx,0,True,"mCherry-LD")
plt.legend()
plt.show()

# %%
test1p2 = Spectral_Analysis.Spectra(False,
                                'C:\\Users\\admin\\Downloads\\09-25-24-selected\\mKO2_spectral_FOV3',
                                'C:\\Users\\admin\\Downloads\\09-25-24-selected\\mKO2_spectral_unmixed_FOV3',
                                6,512,20,8,'M','LD',532)

# %%
plotter, Mindx, LDindx = test1p2.generate_scatter_plot(False,100)
plt.legend(loc='upper right')
plt.show()

# %%
test1p2.generate_normSpectrum(Mindx,0,True,"mKO2-M")
test1p2.generate_normSpectrum(LDindx,0,True,"mCherry-LD")
plt.legend()
plt.show()

# %%
test2 = Spectral_Analysis.Spectra(False,
                                'C:\\Users\\admin\\Downloads\\09-25-24-selected\\mKO2-iRFP_spectral_FOV3',
                                'C:\\Users\\admin\\Downloads\\09-25-24-selected\\mKO2-iRFP_spectral_unmixed_FOV3',
                                10,512,20,5,'M','LD',544)

# %%
plotter, Mindx, LDindx = test2.generate_scatter_plot(False,100)
plt.legend(loc='upper right')
plt.show()

# %%
test2.generate_normSpectrum(Mindx,0,True,True)
test2.generate_normSpectrum(LDindx,0,True,True)
plt.legend()
plt.show()
