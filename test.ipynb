# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reload all modules imported with %aimport every time before executing the Python code typed
# use if constantly editing .py script
# %load_ext autoreload
# %autoreload 1
# %aimport Spectral_Analysis

# %%
# if no longer editing .py script, import the class instead
import Spectral_Analysis

# %%
# Set the Seaborn style and palette
sns.set(style="darkgrid",palette="deep")

# %%
CFP = Spectral_Analysis.Spectra('LargerPnh\\CFP1','LargerPnh\\CFP1_unmixed2',2.5,1024,22,False,'P','V',461.25)

# %%
1024*1024
# Out:
# 1048576

# %%
CFP.generate_indx_select_pix(10)
# Out:
# (array([ 10,  49, 123, 172, 382, 564, 607, 680, 690, 974], dtype=int64),
#  array([628, 882, 327, 276, 739, 767, 429, 934, 752, 849], dtype=int64))

# %%
plotter_2p5, Pindx_2p5, Vindx_2p5 = CFP.generate_scatter_plot(False,10)
plt.legend(loc='upper right')
plt.show()

# %%
CFP.generate_normSpectrum(Pindx_2p5,0,False)
# CFP.generate_normSpectrum(Vindx_2p5,0,True)
plt.legend()
plt.show()

# %%
CFP.generate_normSpectrum(Pindx_2p5,0,True)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\admin\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
GFP = Spectral_Analysis.Spectra('LargerPnh\\GFP1',False,2.5,1024,22,False,'None','None',483)

# %%
ERindx = GFP.generate_indx_select_pix(20)

# %%
GFP.generate_normSpectrum(ERindx,2,False)
plt.show()

# %%
# ?Spec_Analysis.Spectrum_Analysis_no_zstack
# Out:
# Init signature:
# Spec_Analysis.Spectrum_Analysis_no_zstack(
#     raw_data_filename,
#     unmixed_filename,
#     bin_size,
#     Num_pixels,
#     Num_CH,
#     organelle1,
#     organelle2,
#     start_nm,
# )
# Docstring:      For analyzing spectrum of image data w/o zstacks
# File:           c:\users\admin\github\spectral_imaging\spec_analysis.py
# Type:           type
# Subclasses:

# %%
# ?CFP.generate_scatter_plot_varNumpixels
# Out:
# Signature: CFP.generate_scatter_plot_varNumpixels(saturated_pix, Num_toppixels)
# Docstring: <no docstring>
# File:      c:\users\admin\github\spectral_imaging\spec_analysis.py
# Type:      method

# %%
# Leu = Spectral_Analysis.Spectra('Ali_data\\LeuExp100Red_01','Ali_data\\Unmixed.LeuExp100Red_01',6,512,15,16,'M','LD',569)
Leu = Spectral_Analysis.Spectra('Ali_data\\LeuExp100CFP_01','Ali_data\\Unmixed.LeuExp100CFP_01',6,512,19,17,'P','V',443)

# %%
plotter, Mindx, LDindx = Leu.generate_scatter_plot(False,20)
plt.legend(loc='upper right')
plt.show()

# %%
Leu.generate_normSpectrum(Mindx,0,True)
Leu.generate_normSpectrum(LDindx,0,True)
plt.show()

# %%
Mindx
# Out:
# (array([ 45,  47, 194, 196, 269, 271, 273, 348, 385, 415], dtype=int64),
#  array([174, 177, 252, 316, 425, 425, 426, 253,  94, 193], dtype=int64))
