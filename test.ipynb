# %%
import matplotlib.pyplot as plt

# %%
# Reload all modules imported with %aimport every time before executing the Python code typed
# used if constantly editing .py script
# %load_ext autoreload
# %autoreload 1
# %aimport Spectra_Analysis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
CFP = Spectra_Analysis.Spectra_no_z('LargerPnh\\CFP1','LargerPnh\\CFP1_unmixed2',2.5,1024,22,'P','V',461.25)

# %%
plotter_2p5, Pindx_2p5, Vindx_2p5 = CFP.generate_scatter_plot_varNumpixels(False,10)
plt.legend(loc='upper right')
plt.show()

# %%
# ?Spec_Analysis.Spectrum_Analysis_no_zstack
# Out:
# Init signature:
# Spec_Analysis.Spectrum_Analysis_no_zstack(
#     raw_data_filename,
#     unmixed_filename,
#     bin_size,
#     Num_pixels,
#     Num_CH,
#     organelle1,
#     organelle2,
#     start_nm,
# )
# Docstring:      For analyzing spectrum of image data w/o zstacks
# File:           c:\users\admin\github\spectral_imaging\spec_analysis.py
# Type:           type
# Subclasses:

# %%
# ?CFP.generate_scatter_plot_varNumpixels
# Out:
# Signature: CFP.generate_scatter_plot_varNumpixels(saturated_pix, Num_toppixels)
# Docstring: <no docstring>
# File:      c:\users\admin\github\spectral_imaging\spec_analysis.py
# Type:      method
